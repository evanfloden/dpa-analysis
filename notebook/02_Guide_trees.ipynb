# %% [markdown]
# ## Guide trees
# The trees generated below are used both as guide trees in the progressive
# alignment proceedure as well as trees used in the clustering step
# of the regressive alignment proceedure.
#
# The command lines can be found below and in the `templates/trees` directory of the repository.
#
# The generated trees can be found in the `data/trees` directory of this repository.
#
#
# ### Command lines used in the workflow to generate trees
#
# #### Clustal Omega Trees (mBed)
# ```
# custalo -i ${seqs} --guidetree-out ${id}.CLUSTALO.dnd
# ```
#
#
# #### MAFFT PartTree trees
# ```
# t_coffee -other_pg seq_reformat                 \
#           -in ${seqs} -action +seq2dnd parttree \
#           -output newick                        \
#           >> ${id}.MAFFT_PARTTREE.dnd
# ```
#
#
# #### MAFFT trees
# ```
# t_coffee -other_pg seq_reformat \
#          -in ${seqs} -action +seq2dnd mafftdnd \
#          -output newick \
#          >> ${id}.MAFFT.dnd
# ```
#
#
# #### MAFFT-FFTNS1 trees
# ```
# mafft-fftns --retree 1 --anysymbol --treeout ${seqs}
# t_coffee -other_pg seq_reformat \
#          -in ${seqs}.tree -in2 ${seqs} \
#          -input newick \
#          -action +mafftnewick2newick \
#          > ${id}.MAFFT-FFTNS1.dnd
# ```
#
# The following commands were used to generate the trees.

# %%
# Command to change to the base directory of the repository
import os
pwd = os.getcwd()
work_dir=pwd+"/.."
os.chdir(work_dir)
os.getcwd()
# Out:
# '/nfs/users2/cn/efloden/projects/dpa-analysis'

# %%
# !nextflow run main.nf \
             --align_method='CLUSTALO' \
             --tree_method='CLUSTALO,MAFFT_PARTTREE,MAFFT,MAFFT-FFTNS1' \
             --refs='data/refs/*.ref' \
             --seqs='data/combined_seqs/*.fa' \
             --regressive_align=true \
             --standard_align=false \
             --default_align=false \
             --output results \
             -profile crg \
             -with-singularity \
             -resume
# Out:
# N E X T F L O W  ~  version 0.32.0
# Launching `main.nf` [fabulous_minsky] - revision: 77411192a0
# R E G R E S S I V E   M S A   A n a l y s i s  ~  version 0.1"
# ======================================="
# Input sequences (FASTA)                        : data/combined_seqs/*.fa
# Input references (Aligned FASTA)               : data/refs/*.ref
# Input trees (NEWICK)                           : false
# Output directory (DIRECTORY)                   : results
# Alignment methods                              : CLUSTALO
# Tree methods                                   : CLUSTALO,MAFFT_PARTTREE,MAFFT,MAFFT-FFTNS1
# Generate default alignments                    : false
# Generate standard alignments                   : false
# Generate regressive alignments (DPA)           : true
# Bucket Sizes for regressive alignments         : 1000
# Perform evaluation? Requires reference         : true
# Output directory (DIRECTORY)                   : results
#
# [warm up] executor > crg
# WARN: Singularity cache directory has not been defined -- Remote image will be stored in the path: /nfs/users2/cn/efloden/projects/dpa-analysis/work/singularity
# Pulling Singularity image docker://cbcrg/regressive-msa:v0.2.6 [cache /nfs/users2/cn/efloden/projects/dpa-analysis/work/singularity/cbcrg-regressive-msa-v0.2.6.img]
# [96/802597] Submitted process > guide_trees (serpin.MAFFT_PARTTREE)
# [0f/2aeefc] Submitted process > guide_trees (hr.CLUSTALO)
# [06/a20ee0] Submitted process > guide_trees (Sulfotransfer.MAFFT)
# [09/5a97c9] Submitted process > guide_trees (hr.MAFFT_PARTTREE)
# [2a/81299f] Submitted process > guide_trees (Sulfotransfer.CLUSTALO)
# [43/55cc22] Submitted process > guide_trees (hpr.MAFFT)
# [5b/7fa512] Submitted process > guide_trees (serpin.MAFFT-FFTNS1)
# [f8/32df2d] Submitted process > guide_trees (hpr.MAFFT_PARTTREE)
# [4a/2e04a2] Submitted process > guide_trees (hr.MAFFT-FFTNS1)
# [ab/72649a] Submitted process > guide_trees (hpr.MAFFT-FFTNS1)
# [38/7e06f9] Submitted process > guide_trees (Sulfotransfer.MAFFT-FFTNS1)
# [d5/aaa56f] Submitted process > guide_trees (serpin.CLUSTALO)
# [41/23f9a0] Submitted process > guide_trees (hr.MAFFT)
# [00/87e8b7] Submitted process > guide_trees (hpr.CLUSTALO)
# [b8/a5bb39] Submitted process > guide_trees (Sulfotransfer.MAFFT_PARTTREE)
# [05/f86186] Submitted process > guide_trees (serpin.MAFFT)
# [f1/225e20] Submitted process > guide_trees (ldh.CLUSTALO)
# [0b/11eeb6] Submitted process > guide_trees (ricin.CLUSTALO)
# [60/1693be] Submitted process > guide_trees (ricin.MAFFT)
# [31/6739b9] Submitted process > guide_trees (ldh.MAFFT_PARTTREE)
# [f4/5acd13] Submitted process > guide_trees (ricin.MAFFT_PARTTREE)
# [37/cfad8f] Submitted process > guide_trees (ldh.MAFFT)
# [80/329d88] Submitted process > guide_trees (ldh.MAFFT-FFTNS1)
# [f1/fd61c4] Submitted process > guide_trees (kringle.CLUSTALO)
# [4d/fe78db] Submitted process > guide_trees (rub.MAFFT-FFTNS1)
# [ee/7a03ce] Submitted process > guide_trees (tms.CLUSTALO)
# [c1/01aab1] Submitted process > guide_trees (tms.MAFFT-FFTNS1)
# [f3/96cdb9] Submitted process > guide_trees (ricin.MAFFT-FFTNS1)
# [66/04c676] Submitted process > guide_trees (tms.MAFFT)
# [52/c3ff2b] Submitted process > guide_trees (rub.MAFFT_PARTTREE)
# [e5/d6bef4] Submitted process > guide_trees (ChtBD.CLUSTALO)
# [ae/8ec309] Submitted process > guide_trees (rub.MAFFT)
# [5d/a33056] Submitted process > guide_trees (kringle.MAFFT-FFTNS1)
# [4f/301521] Submitted process > guide_trees (tms.MAFFT_PARTTREE)
# [ea/b34e5e] Submitted process > guide_trees (kringle.MAFFT_PARTTREE)
# [e6/39a831] Submitted process > guide_trees (ChtBD.MAFFT_PARTTREE)
# [68/d266a8] Submitted process > guide_trees (rub.CLUSTALO)
# [28/e57183] Submitted process > guide_trees (ChtBD.MAFFT)
# [13/05ac5a] Submitted process > guide_trees (kringle.MAFFT)
# [13/f6c1c7] Submitted process > guide_trees (hormone_rec.MAFFT)
# [e6/32447a] Submitted process > guide_trees (hormone_rec.MAFFT-FFTNS1)
# [17/1d7c39] Submitted process > guide_trees (ghf11.MAFFT_PARTTREE)
# [8f/9d6f89] Submitted process > guide_trees (hormone_rec.MAFFT_PARTTREE)
# [f6/08d7f0] Submitted process > guide_trees (glob.CLUSTALO)
# [6b/aba3a0] Submitted process > guide_trees (ghf11.MAFFT)
# [01/5986d6] Submitted process > guide_trees (ChtBD.MAFFT-FFTNS1)
# [8d/3c61b1] Submitted process > guide_trees (hormone_rec.CLUSTALO)
# [59/91811f] Submitted process > guide_trees (bowman.MAFFT_PARTTREE)
# [1b/d2282b] Submitted process > guide_trees (bowman.CLUSTALO)
# [e0/710bc1] Submitted process > guide_trees (bowman.MAFFT-FFTNS1)
# [c8/8ae7bd] Submitted process > guide_trees (bowman.MAFFT)
# [bf/616f21] Submitted process > guide_trees (ghf11.MAFFT-FFTNS1)
# [1b/853af2] Submitted process > guide_trees (glob.MAFFT_PARTTREE)
# [84/cc50ff] Submitted process > guide_trees (glob.MAFFT)
# [fa/3b928e] Submitted process > guide_trees (ghf11.CLUSTALO)
# [4f/b9ce89] Submitted process > guide_trees (tgfb.MAFFT)
# [13/51f3e7] Submitted process > guide_trees (peroxidase.CLUSTALO)
# [1f/d6edaa] Submitted process > guide_trees (DEATH.MAFFT)
# [be/eea5f4] Submitted process > guide_trees (peroxidase.MAFFT_PARTTREE)
# [d3/ef7ab3] Submitted process > guide_trees (DEATH.CLUSTALO)
# [35/a728c0] Submitted process > guide_trees (peroxidase.MAFFT-FFTNS1)
# [fe/357947] Submitted process > guide_trees (DEATH.MAFFT-FFTNS1)
# [04/e61841] Submitted process > guide_trees (glob.MAFFT-FFTNS1)
# [99/abe91a] Submitted process > guide_trees (DEATH.MAFFT_PARTTREE)
# [3e/3bc457] Submitted process > guide_trees (ghf10.MAFFT_PARTTREE)
# [24/2cccae] Submitted process > guide_trees (ghf10.MAFFT)
# [56/2cc2d0] Submitted process > guide_trees (ghf10.MAFFT-FFTNS1)
# [2d/9200b3] Submitted process > guide_trees (ghf10.CLUSTALO)
# [a7/d9e2ed] Submitted process > guide_trees (tgfb.CLUSTALO)
# [91/e48786] Submitted process > guide_trees (tgfb.MAFFT_PARTTREE)
# [5e/e88ed6] Submitted process > guide_trees (peroxidase.MAFFT)
# [35/90989a] Submitted process > guide_trees (Acetyltransf.CLUSTALO)
# [1b/c9b3d0] Submitted process > guide_trees (Acetyltransf.MAFFT_PARTTREE)
# [f1/2ce898] Submitted process > guide_trees (ghf13.CLUSTALO)
# [8a/9c7956] Submitted process > guide_trees (tgfb.MAFFT-FFTNS1)
# [22/3db9a6] Submitted process > guide_trees (Acetyltransf.MAFFT)
# [c9/c50fe5] Submitted process > guide_trees (ace.CLUSTALO)
# [27/1fb7f5] Submitted process > guide_trees (Acetyltransf.MAFFT-FFTNS1)
# [df/af34a1] Submitted process > guide_trees (ghf13.MAFFT)
# [93/9e41f6] Submitted process > guide_trees (ace.MAFFT_PARTTREE)
# [22/f11b61] Submitted process > guide_trees (ace.MAFFT-FFTNS1)
# [70/59147f] Submitted process > guide_trees (ace.MAFFT)
# [d8/9cac85] Submitted process > guide_trees (ghf13.MAFFT-FFTNS1)
# [0c/132a6b] Submitted process > guide_trees (aat.MAFFT)
# [9a/6472c2] Submitted process > guide_trees (aat.CLUSTALO)
# [97/84faa5] Submitted process > guide_trees (aat.MAFFT_PARTTREE)
# [3d/d8d7f9] Submitted process > guide_trees (ghf13.MAFFT_PARTTREE)
# [3e/648b78] Submitted process > guide_trees (PDZ.MAFFT)
# [59/bc4deb] Submitted process > guide_trees (PDZ.MAFFT_PARTTREE)
# [fa/e9aa08] Submitted process > guide_trees (subt.MAFFT_PARTTREE)
# [f1/15c726] Submitted process > guide_trees (mmp.MAFFT)
# [4f/cf188d] Submitted process > guide_trees (cah.MAFFT)
# [76/58cd51] Submitted process > guide_trees (PDZ.MAFFT-FFTNS1)
# [a0/335109] Submitted process > guide_trees (mmp.MAFFT_PARTTREE)
# [e4/d8e7ca] Submitted process > guide_trees (mmp.CLUSTALO)
# [c0/3a5c0e] Submitted process > guide_trees (subt.CLUSTALO)
# [e3/16cb83] Submitted process > guide_trees (PDZ.CLUSTALO)
# [9f/599d42] Submitted process > guide_trees (mmp.MAFFT-FFTNS1)
# [cb/58de1d] Submitted process > guide_trees (aat.MAFFT-FFTNS1)
# [eb/f2d8f9] Submitted process > guide_trees (cah.CLUSTALO)
# [ac/bf8f20] Submitted process > guide_trees (subt.MAFFT)
# [53/a1b0bf] Submitted process > guide_trees (subt.MAFFT-FFTNS1)
# [fc/8c3322] Submitted process > guide_trees (cah.MAFFT_PARTTREE)
# [68/479a47] Submitted process > guide_trees (int.MAFFT_PARTTREE)
# [52/8bba69] Submitted process > guide_trees (ghf5.MAFFT)
# [70/515f02] Submitted process > guide_trees (Stap_Strp_toxin.CLUSTALO)
# [f1/6e2dfa] Submitted process > guide_trees (Stap_Strp_toxin.MAFFT)
# [5e/e4e61d] Submitted process > guide_trees (ghf5.CLUSTALO)
# [f6/8ac693] Submitted process > guide_trees (int.MAFFT)
# [ee/4df864] Submitted process > guide_trees (int.MAFFT-FFTNS1)
# [05/97fbb1] Submitted process > guide_trees (int.CLUSTALO)
# [13/af14dd] Submitted process > guide_trees (ghf5.MAFFT_PARTTREE)
# [0d/4cc8ba] Submitted process > guide_trees (cah.MAFFT-FFTNS1)
# [db/afd39e] Submitted process > guide_trees (Stap_Strp_toxin.MAFFT-FFTNS1)
# [7e/a2a0cd] Submitted process > guide_trees (ins.MAFFT_PARTTREE)
# [85/2f574a] Submitted process > guide_trees (ghf5.MAFFT-FFTNS1)
# [20/a3180c] Submitted process > guide_trees (Stap_Strp_toxin.MAFFT_PARTTREE)
# [6d/0879a0] Submitted process > guide_trees (ins.CLUSTALO)
# [0e/ab8e9f] Submitted process > guide_trees (ins.MAFFT)
# [d3/f8ddff] Submitted process > guide_trees (msb.MAFFT)
# [9a/5d4c5f] Submitted process > guide_trees (kunitz.MAFFT)
# [91/9be5c7] Submitted process > guide_trees (msb.MAFFT_PARTTREE)
# [09/96b3b2] Submitted process > guide_trees (kunitz.MAFFT_PARTTREE)
# [ad/bb97cd] Submitted process > guide_trees (egf.MAFFT)
# [d5/1657a0] Submitted process > guide_trees (kunitz.CLUSTALO)
# [4f/298ced] Submitted process > guide_trees (msb.MAFFT-FFTNS1)
# [bf/a62e06] Submitted process > guide_trees (hla.CLUSTALO)
# [dd/a19be7] Submitted process > guide_trees (egf.MAFFT_PARTTREE)
# [00/5f2314] Submitted process > guide_trees (ins.MAFFT-FFTNS1)
# [f0/d4e3b8] Submitted process > guide_trees (msb.CLUSTALO)
# [60/3568cf] Submitted process > guide_trees (cytb.MAFFT)
# [1f/ab8d3e] Submitted process > guide_trees (cytb.CLUSTALO)
# [8a/65c9f9] Submitted process > guide_trees (cytb.MAFFT_PARTTREE)
# [36/83f4fc] Submitted process > guide_trees (hla.MAFFT_PARTTREE)
# [0b/f670e2] Submitted process > guide_trees (cytb.MAFFT-FFTNS1)
# [38/698bd3] Submitted process > guide_trees (adh.CLUSTALO)
# [81/0fd529] Submitted process > guide_trees (hla.MAFFT)
# [8a/4d22e2] Submitted process > guide_trees (az.MAFFT)
# [99/d8139f] Submitted process > guide_trees (az.CLUSTALO)
# [1c/a2f2df] Submitted process > guide_trees (kunitz.MAFFT-FFTNS1)
# [e8/49216b] Submitted process > guide_trees (egf.MAFFT-FFTNS1)
# [4f/c16248] Submitted process > guide_trees (az.MAFFT-FFTNS1)
# [29/77d7ff] Submitted process > guide_trees (egf.CLUSTALO)
# [9e/f79c10] Submitted process > guide_trees (hla.MAFFT-FFTNS1)
# [10/f3d7f6] Submitted process > guide_trees (adh.MAFFT_PARTTREE)
# [91/cdda79] Submitted process > guide_trees (HMG_box.MAFFT)
# [ea/3be0a6] Submitted process > guide_trees (HMG_box.MAFFT_PARTTREE)
# [5e/fffad2] Submitted process > guide_trees (GEL.CLUSTALO)
# [18/22ad95] Submitted process > guide_trees (asp.MAFFT_PARTTREE)
# [29/4acac0] Submitted process > guide_trees (GEL.MAFFT-FFTNS1)
# [4d/cf093f] Submitted process > guide_trees (GEL.MAFFT_PARTTREE)
# [6d/e6b5ff] Submitted process > guide_trees (sodfe.MAFFT_PARTTREE)
# [bb/1550b8] Submitted process > guide_trees (adh.MAFFT)
# [8b/c23ed7] Submitted process > guide_trees (adh.MAFFT-FFTNS1)
# [fb/2cd7c0] Submitted process > guide_trees (az.MAFFT_PARTTREE)
# [13/f898ff] Submitted process > guide_trees (sodfe.MAFFT-FFTNS1)
# [3b/d30f8e] Submitted process > guide_trees (asp.CLUSTALO)
# [1b/e1546d] Submitted process > guide_trees (profilin.MAFFT-FFTNS1)
# [08/d0fe16] Submitted process > guide_trees (asp.MAFFT)
# [ec/f7ed0d] Submitted process > guide_trees (asp.MAFFT-FFTNS1)
# [0b/fc7408] Submitted process > guide_trees (profilin.MAFFT)
# [e5/2918a5] Submitted process > guide_trees (il8.MAFFT)
# [2f/d5a3ea] Submitted process > guide_trees (sodfe.CLUSTALO)
# [bd/a54f63] Submitted process > guide_trees (HMG_box.MAFFT-FFTNS1)
# [ee/6dfa20] Submitted process > guide_trees (aldosered.CLUSTALO)
# [34/b989e8] Submitted process > guide_trees (profilin.CLUSTALO)
# [9f/85617f] Submitted process > guide_trees (aldosered.MAFFT)
# [2f/7aa4d8] Submitted process > guide_trees (profilin.MAFFT_PARTTREE)
# [46/d18313] Submitted process > guide_trees (HMG_box.CLUSTALO)
# [06/1dd610] Submitted process > guide_trees (myb_DNA-binding.MAFFT)
# [c4/434aa0] Submitted process > guide_trees (GEL.MAFFT)
# [70/bf9e7c] Submitted process > guide_trees (myb_DNA-binding.MAFFT_PARTTREE)
# [1a/312743] Submitted process > guide_trees (il8.CLUSTALO)
# [8f/e649df] Submitted process > guide_trees (cryst.MAFFT)
# [7f/7afa6a] Submitted process > guide_trees (sodfe.MAFFT)
# [1b/d2168b] Submitted process > guide_trees (cryst.CLUSTALO)
# [a6/3886b8] Submitted process > guide_trees (cryst.MAFFT_PARTTREE)
# [40/161374] Submitted process > guide_trees (aldosered.MAFFT_PARTTREE)
# [a6/919d46] Submitted process > guide_trees (Rhodanese.MAFFT-FFTNS1)
# [af/5f8c2d] Submitted process > guide_trees (il8.MAFFT_PARTTREE)
# [6d/fdbead] Submitted process > guide_trees (Rhodanese.MAFFT_PARTTREE)
# [80/4f6ff1] Submitted process > guide_trees (mofe.MAFFT_PARTTREE)
# [5b/632599] Submitted process > guide_trees (mofe.MAFFT-FFTNS1)
# [af/8aff64] Submitted process > guide_trees (cryst.MAFFT-FFTNS1)
# [2b/684e15] Submitted process > guide_trees (myb_DNA-binding.MAFFT-FFTNS1)
# [24/3d939c] Submitted process > guide_trees (trfl.MAFFT_PARTTREE)
# [fe/6b250a] Submitted process > guide_trees (trfl.MAFFT)
# [90/439eed] Submitted process > guide_trees (il8.MAFFT-FFTNS1)
# [e6/183577] Submitted process > guide_trees (LIM.MAFFT)
# [d7/98a10b] Submitted process > guide_trees (aldosered.MAFFT-FFTNS1)
# [30/0df1f5] Submitted process > guide_trees (Rhodanese.CLUSTALO)
# [fc/ebbd43] Submitted process > guide_trees (LIM.MAFFT_PARTTREE)
# [2b/1c1a79] Submitted process > guide_trees (LIM.MAFFT-FFTNS1)
# [ff/e0dc11] Submitted process > guide_trees (myb_DNA-binding.CLUSTALO)
# [80/59de12] Submitted process > guide_trees (gpdh.MAFFT)
# [36/cbcb0d] Submitted process > guide_trees (gpdh.MAFFT_PARTTREE)
# [75/06fa50] Submitted process > guide_trees (Rhodanese.MAFFT)
# [0b/945d70] Submitted process > guide_trees (gpdh.CLUSTALO)
# [b3/d78e0f] Submitted process > guide_trees (mofe.MAFFT)
# [e4/cf596e] Submitted process > guide_trees (biotin_lipoyl.MAFFT-FFTNS1)
# [ff/d65c73] Submitted process > guide_trees (biotin_lipoyl.MAFFT_PARTTREE)
# [c0/9bf18f] Submitted process > guide_trees (HLH.MAFFT-FFTNS1)
# [50/17f8b2] Submitted process > guide_trees (mofe.CLUSTALO)
# [8f/4843fc] Submitted process > guide_trees (HLH.CLUSTALO)
# [e9/d8acdf] Submitted process > guide_trees (trfl.CLUSTALO)
# [48/019df5] Submitted process > guide_trees (trfl.MAFFT-FFTNS1)
# [17/0209d4] Submitted process > guide_trees (HLH.MAFFT)
# [40/291168] Submitted process > guide_trees (ltn.CLUSTALO)
# [88/53744b] Submitted process > guide_trees (biotin_lipoyl.CLUSTALO)
# [76/50bc4a] Submitted process > guide_trees (toxin.MAFFT-FFTNS1)
# [f4/100892] Submitted process > guide_trees (ltn.MAFFT-FFTNS1)
# [65/406191] Submitted process > guide_trees (LIM.CLUSTALO)
# [f4/a97887] Submitted process > guide_trees (gluts.MAFFT_PARTTREE)
# [22/302a9c] Submitted process > guide_trees (toxin.MAFFT)
# [b8/e1ea83] Submitted process > guide_trees (gluts.MAFFT)
# [33/faa0ac] Submitted process > guide_trees (biotin_lipoyl.MAFFT)
# [4f/982ffe] Submitted process > guide_trees (proteasome.MAFFT)
# [d7/64a9d4] Submitted process > guide_trees (proteasome.MAFFT_PARTTREE)
# [36/5ffd86] Submitted process > guide_trees (gluts.MAFFT-FFTNS1)
# [51/e96a4c] Submitted process > guide_trees (gpdh.MAFFT-FFTNS1)
# [ae/78ef95] Submitted process > guide_trees (uce.MAFFT)
# [ab/c2cd51] Submitted process > guide_trees (proteasome.MAFFT-FFTNS1)
# [f3/e46657] Submitted process > guide_trees (uce.MAFFT_PARTTREE)
# [b8/d480d9] Submitted process > guide_trees (uce.MAFFT-FFTNS1)
# [59/737f93] Submitted process > guide_trees (phc.MAFFT)
# [15/31c197] Submitted process > guide_trees (ltn.MAFFT_PARTTREE)
# [e3/8ca72b] Submitted process > guide_trees (phc.MAFFT_PARTTREE)
# [d9/291c92] Submitted process > guide_trees (HLH.MAFFT_PARTTREE)
# [0d/e26e4b] Submitted process > guide_trees (OTCace.MAFFT)
# [fb/508150] Submitted process > guide_trees (OTCace.CLUSTALO)
# [54/5c492a] Submitted process > guide_trees (toxin.CLUSTALO)
# [cb/5e6be4] Submitted process > guide_trees (slectin.MAFFT_PARTTREE)
# [6a/58eb43] Submitted process > guide_trees (toxin.MAFFT_PARTTREE)
# [a2/737527] Submitted process > guide_trees (ltn.MAFFT)
# [ec/693a19] Submitted process > guide_trees (slectin.MAFFT)
# [2f/ca554f] Submitted process > guide_trees (slectin.MAFFT-FFTNS1)
# [b6/cce7d8] Submitted process > guide_trees (gluts.CLUSTALO)
# [ab/16087c] Submitted process > guide_trees (scorptoxin.MAFFT_PARTTREE)
# [3c/f9f3c0] Submitted process > guide_trees (proteasome.CLUSTALO)
# [95/968390] Submitted process > guide_trees (uce.CLUSTALO)
# [07/6c2a75] Submitted process > guide_trees (OTCace.MAFFT-FFTNS1)
# [c8/15fa61] Submitted process > guide_trees (scorptoxin.MAFFT-FFTNS1)
# [7f/dc6ebe] Submitted process > guide_trees (oxidored_q6.MAFFT_PARTTREE)
# [3c/dad13c] Submitted process > guide_trees (slectin.CLUSTALO)
# [96/0544a3] Submitted process > guide_trees (scorptoxin.MAFFT)
# [f0/5cc730] Submitted process > guide_trees (p450.CLUSTALO)
# [83/9d171d] Submitted process > guide_trees (OTCace.MAFFT_PARTTREE)
# [61/6d98a5] Submitted process > guide_trees (phc.MAFFT-FFTNS1)
# [02/51cde0] Submitted process > guide_trees (oxidored_q6.CLUSTALO)
# [51/bf2c6c] Submitted process > guide_trees (seatoxin.MAFFT_PARTTREE)
# [ee/e89416] Submitted process > guide_trees (seatoxin.MAFFT-FFTNS1)
# [f8/e2f099] Submitted process > guide_trees (seatoxin.CLUSTALO)
# [cd/9a500f] Submitted process > guide_trees (Ald_Xan_dh_2.CLUSTALO)
# [10/730d88] Submitted process > guide_trees (Ald_Xan_dh_2.MAFFT)
# [83/1fdc24] Submitted process > guide_trees (oxidored_q6.MAFFT)
# [f6/e2bd28] Submitted process > guide_trees (Ald_Xan_dh_2.MAFFT-FFTNS1)
# [e4/4a7362] Submitted process > guide_trees (tim.CLUSTALO)
# [3f/9fef87] Submitted process > guide_trees (phc.CLUSTALO)
# [e8/b76d25] Submitted process > guide_trees (tim.MAFFT_PARTTREE)
# [aa/2edcf1] Submitted process > guide_trees (scorptoxin.CLUSTALO)
# [24/b6a85a] Submitted process > guide_trees (lyase_1.CLUSTALO)
# [41/6dcdd4] Submitted process > guide_trees (lyase_1.MAFFT-FFTNS1)
# [98/ef01d3] Submitted process > guide_trees (p450.MAFFT)
# [f4/989883] Submitted process > guide_trees (lyase_1.MAFFT)
# [10/f45f5d] Submitted process > guide_trees (phoslip.CLUSTALO)
# [08/34c882] Submitted process > guide_trees (phoslip.MAFFT_PARTTREE)
# [d0/8edf1f] Submitted process > guide_trees (oxidored_q6.MAFFT-FFTNS1)
# [05/8b2ccd] Submitted process > guide_trees (phoslip.MAFFT)
# [69/2e7b6b] Submitted process > guide_trees (p450.MAFFT-FFTNS1)
# [69/b0da2e] Submitted process > guide_trees (p450.MAFFT_PARTTREE)
# [c1/4118fc] Submitted process > guide_trees (cyt3.CLUSTALO)
# [dc/a11856] Submitted process > guide_trees (seatoxin.MAFFT)
# [ac/383b05] Submitted process > guide_trees (cyt3.MAFFT-FFTNS1)
# [1b/17e7fb] Submitted process > guide_trees (tRNA-synt_2b.CLUSTALO)
# [a1/ad62b4] Submitted process > guide_trees (Ald_Xan_dh_2.MAFFT_PARTTREE)
# [3a/8d0c7d] Submitted process > guide_trees (tim.MAFFT)
# [5a/ae6843] Submitted process > guide_trees (rvp.CLUSTALO)
# [22/fb945e] Submitted process > guide_trees (tRNA-synt_2b.MAFFT-FFTNS1)
# [2e/60b463] Submitted process > guide_trees (tim.MAFFT-FFTNS1)
# [7a/795f45] Submitted process > guide_trees (lyase_1.MAFFT_PARTTREE)
# [9c/6e761f] Submitted process > guide_trees (cyt3.MAFFT_PARTTREE)
# [30/eba1e1] Submitted process > guide_trees (cyclo.MAFFT-FFTNS1)
# [5a/60c9e7] Submitted process > guide_trees (rvp.MAFFT)
# [86/0e2516] Submitted process > guide_trees (phoslip.MAFFT-FFTNS1)
# [e5/82438a] Submitted process > guide_trees (rrm.MAFFT_PARTTREE)
# [7f/56aee6] Submitted process > guide_trees (DMRL_synthase.MAFFT)
# [11/c60454] Submitted process > guide_trees (tRNA-synt_2b.MAFFT_PARTTREE)
# [63/45f624] Submitted process > guide_trees (rvp.MAFFT_PARTTREE)
# [53/dc5170] Submitted process > guide_trees (KAS.CLUSTALO)
# [f2/59b3c4] Submitted process > guide_trees (rvp.MAFFT-FFTNS1)
# [26/0424f9] Submitted process > guide_trees (cyt3.MAFFT)
# [ae/9dd2d8] Submitted process > guide_trees (KAS.MAFFT)
# [43/a45b3a] Submitted process > guide_trees (KAS.MAFFT_PARTTREE)
# [05/6aa3ec] Submitted process > guide_trees (rhv.CLUSTALO)
# [38/f95a76] Submitted process > guide_trees (KAS.MAFFT-FFTNS1)
# [ca/cf347d] Submitted process > guide_trees (tRNA-synt_2b.MAFFT)
# [98/fdc197] Submitted process > guide_trees (blm.CLUSTALO)
# [44/ff2a11] Submitted process > guide_trees (cyclo.MAFFT_PARTTREE)
# [d0/24de41] Submitted process > guide_trees (rhv.MAFFT)
# [c7/9b8218] Submitted process > guide_trees (cyclo.MAFFT)
# [42/115067] Submitted process > guide_trees (cyclo.CLUSTALO)
# [32/f5fc75] Submitted process > guide_trees (rrm.CLUSTALO)
# [42/87eff5] Submitted process > guide_trees (rrm.MAFFT)
# [32/1767d3] Submitted process > guide_trees (rrm.MAFFT-FFTNS1)
# [00/0699da] Submitted process > guide_trees (flav.MAFFT)
# [be/d4d356] Submitted process > guide_trees (flav.MAFFT-FFTNS1)
# [36/69b95d] Submitted process > guide_trees (rhv.MAFFT-FFTNS1)
# [ef/2e787e] Submitted process > guide_trees (DMRL_synthase.CLUSTALO)
# [56/17041b] Submitted process > guide_trees (ghf22.CLUSTALO)
# [a5/6dce75] Submitted process > guide_trees (DMRL_synthase.MAFFT_PARTTREE)
# [ce/c2131b] Submitted process > guide_trees (DMRL_synthase.MAFFT-FFTNS1)
# [3b/417971] Submitted process > guide_trees (ghf22.MAFFT)
# [05/8a1581] Submitted process > guide_trees (TNF.MAFFT)
# [59/c59bca] Submitted process > guide_trees (ghf22.MAFFT_PARTTREE)
# [87/e7d7db] Submitted process > guide_trees (rhv.MAFFT_PARTTREE)
# [61/4cf26b] Submitted process > guide_trees (blmb.CLUSTALO)
# [04/715736] Submitted process > guide_trees (blmb.MAFFT_PARTTREE)
# [a3/b04b81] Submitted process > guide_trees (blm.MAFFT)
# [75/ffae93] Submitted process > guide_trees (blmb.MAFFT-FFTNS1)
# [62/362f9f] Submitted process > guide_trees (blm.MAFFT-FFTNS1)
# [a3/6bbd98] Submitted process > guide_trees (ghf22.MAFFT-FFTNS1)
# [e8/03300e] Submitted process > guide_trees (ghf1.CLUSTALO)
# [5d/c844a7] Submitted process > guide_trees (ghf1.MAFFT)
# [64/50df0c] Submitted process > guide_trees (blm.MAFFT_PARTTREE)
# [6e/9ac360] Submitted process > guide_trees (TNF.CLUSTALO)
# [6d/a445e4] Submitted process > guide_trees (ghf1.MAFFT_PARTTREE)
# [8a/60c6d5] Submitted process > guide_trees (ghf1.MAFFT-FFTNS1)
# [4f/16da51] Submitted process > guide_trees (cys.MAFFT)
# [54/5e74de] Submitted process > guide_trees (annexin.CLUSTALO)
# [c7/20489a] Submitted process > guide_trees (cys.MAFFT_PARTTREE)
# [03/3147ee] Submitted process > guide_trees (flav.CLUSTALO)
# [5b/aedf88] Submitted process > guide_trees (cys.CLUSTALO)
# [2d/bf37e2] Submitted process > guide_trees (cys.MAFFT-FFTNS1)
# [89/2b0279] Submitted process > guide_trees (flav.MAFFT_PARTTREE)
# [f1/dd9cd6] Submitted process > guide_trees (annexin.MAFFT_PARTTREE)
# [65/7fed84] Submitted process > guide_trees (icd.MAFFT)
# [bb/d19eb8] Submitted process > guide_trees (icd.MAFFT_PARTTREE)
# [d4/0b8797] Submitted process > guide_trees (TNF.MAFFT_PARTTREE)
# [fa/05a0e8] Submitted process > guide_trees (sdr.MAFFT-FFTNS1)
# [34/626b15] Submitted process > guide_trees (icd.MAFFT-FFTNS1)
# [3f/abafa4] Submitted process > guide_trees (sdr.CLUSTALO)
# [47/19eb4a] Submitted process > guide_trees (TNF.MAFFT-FFTNS1)
# [f3/7af196] Submitted process > guide_trees (zf-CCHH.MAFFT_PARTTREE)
# [3f/cea08f] Submitted process > guide_trees (zf-CCHH.CLUSTALO)
# [33/900024] Submitted process > guide_trees (rnasemam.CLUSTALO)
# [5a/60c9e7] NOTE: Process `guide_trees (rvp.MAFFT)` terminated with an error exit status (1) -- Execution is retried (1)
# [12/6c0bab] Submitted process > guide_trees (blmb.MAFFT)
# [f6/71cb10] Submitted process > guide_trees (zf-CCHH.MAFFT)
# [78/a1afeb] Submitted process > guide_trees (annexin.MAFFT-FFTNS1)
# [70/743bda] Submitted process > guide_trees (zf-CCHH.MAFFT-FFTNS1)
# [34/2c6d2d] Submitted process > guide_trees (rnasemam.MAFFT)
# [e0/f04a95] Submitted process > guide_trees (hip.CLUSTALO)
# [dc/cc8266] Submitted process > guide_trees (hip.MAFFT_PARTTREE)
# [d2/f3d3eb] Submitted process > guide_trees (annexin.MAFFT)
# [37/d1631c] Submitted process > guide_trees (hip.MAFFT-FFTNS1)
# [40/d978a8] Submitted process > guide_trees (hip.MAFFT)
# [75/20468b] Submitted process > guide_trees (hom.CLUSTALO)
# [03/c03dbe] Submitted process > guide_trees (hom.MAFFT_PARTTREE)
# [c3/1914fa] Submitted process > guide_trees (sdr.MAFFT)
# [e8/f7b5d6] Submitted process > guide_trees (aadh.CLUSTALO)
# [5f/351c23] Submitted process > guide_trees (icd.CLUSTALO)
# [11/5a9bb9] Submitted process > guide_trees (sodcu.CLUSTALO)
# [40/008c19] Submitted process > guide_trees (sodcu.MAFFT)
# [00/4ae5f5] Submitted process > guide_trees (aadh.MAFFT)
# [74/d5da5b] Submitted process > guide_trees (sdr.MAFFT_PARTTREE)
# [bd/48247c] Submitted process > guide_trees (sodcu.MAFFT-FFTNS1)
# [12/4ad6ad] Submitted process > guide_trees (sti.CLUSTALO)
# [a8/3bc177] Submitted process > guide_trees (rnasemam.MAFFT_PARTTREE)
# [00/44d33b] Submitted process > guide_trees (sodcu.MAFFT_PARTTREE)
# [31/b715c7] Submitted process > guide_trees (sti.MAFFT)
# [79/3fc7d5] Submitted process > guide_trees (hom.MAFFT-FFTNS1)
# [ff/428d18] Submitted process > guide_trees (sti.MAFFT-FFTNS1)
# [b7/ce65cc] Submitted process > guide_trees (hom.MAFFT)
# [cc/145288] Submitted process > guide_trees (rnasemam.MAFFT-FFTNS1)
# [b7/6d5577] Submitted process > guide_trees (aadh.MAFFT-FFTNS1)
# [6c/d36809] Submitted process > guide_trees (aadh.MAFFT_PARTTREE)
# [7b/456dc5] Submitted process > guide_trees (sti.MAFFT_PARTTREE)
# [00/89cfaa] Submitted process > regressive_alignment (serpin.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [e4/a396d6] Submitted process > regressive_alignment (hr.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [d6/f73c44] Submitted process > regressive_alignment (hpr.CLUSTALO.DPA.1000.MAFFT)
# [e6/7bea67] Submitted process > regressive_alignment (hpr.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [f9/d909bd] Submitted process > regressive_alignment (hr.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [1c/11fef5] Submitted process > regressive_alignment (hpr.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [7a/6e4bf0] Submitted process > regressive_alignment (Sulfotransfer.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [7f/100011] Submitted process > regressive_alignment (hr.CLUSTALO.DPA.1000.MAFFT)
# [d5/11d00d] Submitted process > regressive_alignment (Sulfotransfer.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [f2/59b3c4] NOTE: Process `guide_trees (rvp.MAFFT-FFTNS1)` terminated with an error exit status (1) -- Execution is retried (1)
# [ea/985068] Submitted process > regressive_alignment (ricin.CLUSTALO.DPA.1000.CLUSTALO)
# [25/e91bc0] Submitted process > regressive_alignment (ricin.CLUSTALO.DPA.1000.MAFFT)
# [c1/238d79] Submitted process > regressive_alignment (ldh.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [75/876edc] Submitted process > regressive_alignment (ricin.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [d9/5ff990] Submitted process > regressive_alignment (kringle.CLUSTALO.DPA.1000.CLUSTALO)
# [95/dda9fd] Submitted process > regressive_alignment (rub.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [89/e20eed] Submitted process > regressive_alignment (tms.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [3b/369189] Submitted process > regressive_alignment (ricin.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [83/4652ad] Submitted process > regressive_alignment (tms.CLUSTALO.DPA.1000.MAFFT)
# [14/21cb84] Submitted process > regressive_alignment (rub.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [f6/71cb10] NOTE: Process `guide_trees (zf-CCHH.MAFFT)` terminated with an error exit status (1) -- Execution is retried (1)
# [fe/d6cd19] Submitted process > regressive_alignment (ChtBD.CLUSTALO.DPA.1000.CLUSTALO)
# [0a/276d79] Submitted process > regressive_alignment (rub.CLUSTALO.DPA.1000.MAFFT)
# [ea/11cd5f] Submitted process > regressive_alignment (kringle.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [77/8e95cf] Submitted process > regressive_alignment (tms.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [ab/043cad] Submitted process > regressive_alignment (kringle.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [b8/6219be] Submitted process > regressive_alignment (ChtBD.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [bf/476176] Submitted process > regressive_alignment (rub.CLUSTALO.DPA.1000.CLUSTALO)
# [67/fc3cc3] Submitted process > regressive_alignment (ChtBD.CLUSTALO.DPA.1000.MAFFT)
# [a3/cfef04] Submitted process > regressive_alignment (kringle.CLUSTALO.DPA.1000.MAFFT)
# [19/8376e1] Submitted process > regressive_alignment (hormone_rec.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [94/239eb1] Submitted process > regressive_alignment (ghf11.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [4a/d5a1d7] Submitted process > regressive_alignment (hormone_rec.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [30/f05c55] Submitted process > regressive_alignment (ghf11.CLUSTALO.DPA.1000.MAFFT)
# [a5/4bceb2] Submitted process > regressive_alignment (ChtBD.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [8a/b5dedd] Submitted process > regressive_alignment (bowman.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [f5/f95a5d] Submitted process > regressive_alignment (bowman.CLUSTALO.DPA.1000.CLUSTALO)
# [70/743bda] NOTE: Process `guide_trees (zf-CCHH.MAFFT-FFTNS1)` terminated with an error exit status (1) -- Execution is retried (1)
# [ec/2fd76d] Submitted process > regressive_alignment (bowman.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [d3/383d58] Submitted process > regressive_alignment (bowman.CLUSTALO.DPA.1000.MAFFT)
# [d8/a72433] Submitted process > regressive_alignment (ghf11.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [1a/c24d68] Submitted process > regressive_alignment (glob.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [db/255689] Submitted process > regressive_alignment (glob.CLUSTALO.DPA.1000.MAFFT)
# [8a/363770] Submitted process > regressive_alignment (ghf11.CLUSTALO.DPA.1000.CLUSTALO)
# [7e/6c9b26] Submitted process > regressive_alignment (tgfb.CLUSTALO.DPA.1000.MAFFT)
# [83/b5acef] Submitted process > regressive_alignment (DEATH.CLUSTALO.DPA.1000.MAFFT)
# [02/1e0883] Submitted process > regressive_alignment (peroxidase.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [5c/86cf42] Submitted process > regressive_alignment (DEATH.CLUSTALO.DPA.1000.CLUSTALO)
# [84/042ffb] Submitted process > regressive_alignment (peroxidase.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [a2/1cecf1] Submitted process > regressive_alignment (DEATH.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [4c/01e1ef] Submitted process > regressive_alignment (glob.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [cc/3119ae] Submitted process > regressive_alignment (DEATH.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [61/f84f21] Submitted process > regressive_alignment (ghf10.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [e1/df2104] Submitted process > regressive_alignment (ghf10.CLUSTALO.DPA.1000.MAFFT)
# [d8/14e00b] Submitted process > regressive_alignment (ghf10.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [24/87f8d5] Submitted process > regressive_alignment (tgfb.CLUSTALO.DPA.1000.CLUSTALO)
# [0b/9e1cf3] Submitted process > regressive_alignment (tgfb.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [eb/429783] Submitted process > regressive_alignment (Acetyltransf.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [c6/16fbda] Submitted process > regressive_alignment (tgfb.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [29/2cb11f] Submitted process > regressive_alignment (ace.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [48/c92f9a] Submitted process > regressive_alignment (aat.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [32/d145ef] Submitted process > regressive_alignment (ghf13.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [7a/b4c9be] Submitted process > regressive_alignment (PDZ.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [9c/b97a17] Submitted process > regressive_alignment (subt.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [bb/42253c] Submitted process > regressive_alignment (mmp.CLUSTALO.DPA.1000.MAFFT)
# [42/561f01] Submitted process > regressive_alignment (cah.CLUSTALO.DPA.1000.MAFFT)
# [7b/72eccf] Submitted process > regressive_alignment (mmp.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [64/8902ed] Submitted process > regressive_alignment (mmp.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [91/7a337d] Submitted process > regressive_alignment (hr.CLUSTALO.DPA.1000.CLUSTALO)
# [e0/6e62b6] Submitted process > regressive_alignment (Sulfotransfer.CLUSTALO.DPA.1000.MAFFT)
# [31/1e78da] Submitted process > regressive_alignment (serpin.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [08/b42b49] Submitted process > regressive_alignment (hpr.CLUSTALO.DPA.1000.CLUSTALO)
# [7d/c7a0f0] Submitted process > regressive_alignment (serpin.CLUSTALO.DPA.1000.MAFFT)
# [07/f82424] Submitted process > regressive_alignment (ldh.CLUSTALO.DPA.1000.MAFFT)
# [e3/b248a1] Submitted process > regressive_alignment (ldh.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [26/6b1394] Submitted process > regressive_alignment (hormone_rec.CLUSTALO.DPA.1000.MAFFT)
# [63/2bd612] Submitted process > regressive_alignment (glob.CLUSTALO.DPA.1000.CLUSTALO)
# [70/ddffa1] Submitted process > regressive_alignment (cah.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [ae/d016d0] Submitted process > regressive_alignment (int.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [e0/8be9fb] Submitted process > regressive_alignment (Stap_Strp_toxin.CLUSTALO.DPA.1000.CLUSTALO)
# [3d/0616ed] Submitted process > regressive_alignment (Stap_Strp_toxin.CLUSTALO.DPA.1000.MAFFT)
# [bb/37a153] Submitted process > regressive_alignment (ghf5.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [c7/eed386] Submitted process > regressive_alignment (cah.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [d6/25557c] Submitted process > regressive_alignment (Stap_Strp_toxin.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [ef/066531] Submitted process > regressive_alignment (ins.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [fc/4ae484] Submitted process > regressive_alignment (ghf5.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [36/d9f2c4] Submitted process > regressive_alignment (Stap_Strp_toxin.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [c8/68d0ea] Submitted process > regressive_alignment (ins.CLUSTALO.DPA.1000.CLUSTALO)
# [84/d35340] Submitted process > regressive_alignment (ins.CLUSTALO.DPA.1000.MAFFT)
# [53/df4fc0] Submitted process > regressive_alignment (kunitz.CLUSTALO.DPA.1000.MAFFT)
# [74/3d6746] Submitted process > regressive_alignment (msb.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [ba/d6f6c7] Submitted process > regressive_alignment (kunitz.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [58/efc743] Submitted process > regressive_alignment (egf.CLUSTALO.DPA.1000.MAFFT)
# [99/7eb069] Submitted process > regressive_alignment (kunitz.CLUSTALO.DPA.1000.CLUSTALO)
# [40/76fd9d] Submitted process > regressive_alignment (msb.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [12/7c0872] Submitted process > regressive_alignment (egf.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [5a/ef833c] Submitted process > regressive_alignment (ins.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [45/ed7c57] Submitted process > regressive_alignment (cytb.CLUSTALO.DPA.1000.MAFFT)
# [9e/d571c6] Submitted process > regressive_alignment (cytb.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [1d/0621de] Submitted process > regressive_alignment (hla.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [d7/4813b8] Submitted process > regressive_alignment (cytb.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [16/98d043] Submitted process > regressive_alignment (az.CLUSTALO.DPA.1000.MAFFT)
# [0e/3be62b] Submitted process > regressive_alignment (kunitz.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [15/3bee11] Submitted process > regressive_alignment (egf.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [d9/c29650] Submitted process > regressive_alignment (az.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [f1/038645] Submitted process > regressive_alignment (adh.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [da/9c7189] Submitted process > regressive_alignment (HMG_box.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [32/82a9b4] Submitted process > regressive_alignment (asp.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [c1/e78ac8] Submitted process > regressive_alignment (GEL.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [56/f4c3ee] Submitted process > regressive_alignment (GEL.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [3e/6b5cf2] Submitted process > regressive_alignment (sodfe.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [4d/107db2] Submitted process > regressive_alignment (az.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [e9/1dcf71] Submitted process > regressive_alignment (sodfe.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [b2/14b992] Submitted process > regressive_alignment (profilin.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [f3/af2653] Submitted process > regressive_alignment (profilin.CLUSTALO.DPA.1000.MAFFT)
# [69/08ae82] Submitted process > regressive_alignment (il8.CLUSTALO.DPA.1000.MAFFT)
# [f8/f70859] Submitted process > regressive_alignment (ghf10.CLUSTALO.DPA.1000.CLUSTALO)
# [ef/70c1ef] Submitted process > regressive_alignment (ace.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [82/650541] Submitted process > regressive_alignment (mmp.CLUSTALO.DPA.1000.CLUSTALO)
# [9c/0c65c3] Submitted process > regressive_alignment (cah.CLUSTALO.DPA.1000.CLUSTALO)
# [24/18d011] Submitted process > regressive_alignment (profilin.CLUSTALO.DPA.1000.CLUSTALO)
# [43/6dbf90] Submitted process > regressive_alignment (tms.CLUSTALO.DPA.1000.CLUSTALO)
# [47/cc4011] Submitted process > regressive_alignment (ghf5.CLUSTALO.DPA.1000.MAFFT)
# [11/51a957] Submitted process > regressive_alignment (int.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [c9/5a9a22] Submitted process > regressive_alignment (msb.CLUSTALO.DPA.1000.MAFFT)
# [e6/63dd3c] Submitted process > regressive_alignment (cytb.CLUSTALO.DPA.1000.CLUSTALO)
# [23/fa8e9e] Submitted process > regressive_alignment (az.CLUSTALO.DPA.1000.CLUSTALO)
# [56/3bdf2d] Submitted process > regressive_alignment (egf.CLUSTALO.DPA.1000.CLUSTALO)
# [a9/fbfbd1] Submitted process > regressive_alignment (HMG_box.CLUSTALO.DPA.1000.MAFFT)
# [19/9a7e2b] Submitted process > regressive_alignment (GEL.CLUSTALO.DPA.1000.CLUSTALO)
# [81/3a47d2] Submitted process > regressive_alignment (asp.CLUSTALO.DPA.1000.MAFFT)
# [f8/82e8dd] Submitted process > regressive_alignment (asp.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [c8/1ea75e] Submitted process > regressive_alignment (sodfe.CLUSTALO.DPA.1000.CLUSTALO)
# [20/fd0292] Submitted process > regressive_alignment (HMG_box.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [e7/d6940e] Submitted process > regressive_alignment (profilin.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [80/90bf71] Submitted process > regressive_alignment (HMG_box.CLUSTALO.DPA.1000.CLUSTALO)
# [ab/3a9869] Submitted process > regressive_alignment (GEL.CLUSTALO.DPA.1000.MAFFT)
# [27/d4fa5c] Submitted process > regressive_alignment (myb_DNA-binding.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [45/bbdb1b] Submitted process > regressive_alignment (il8.CLUSTALO.DPA.1000.CLUSTALO)
# [98/96b334] Submitted process > regressive_alignment (cryst.CLUSTALO.DPA.1000.MAFFT)
# [50/71f5cd] Submitted process > regressive_alignment (sodfe.CLUSTALO.DPA.1000.MAFFT)
# [c2/2e4e2a] Submitted process > regressive_alignment (cryst.CLUSTALO.DPA.1000.CLUSTALO)
# [3a/a7d220] Submitted process > regressive_alignment (cryst.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [0c/7bb0a5] Submitted process > regressive_alignment (aldosered.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [1d/d5cbc1] Submitted process > regressive_alignment (il8.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [7e/a05b73] Submitted process > regressive_alignment (Rhodanese.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [6c/0ddfa2] Submitted process > regressive_alignment (mofe.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [44/8f05a5] Submitted process > regressive_alignment (mofe.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [fd/7cc6ae] Submitted process > regressive_alignment (cryst.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [66/64fecd] Submitted process > regressive_alignment (myb_DNA-binding.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [7b/d7c5a2] Submitted process > regressive_alignment (trfl.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [41/27fe89] Submitted process > regressive_alignment (trfl.CLUSTALO.DPA.1000.MAFFT)
# [35/3d4cb6] Submitted process > regressive_alignment (il8.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [ee/361802] Submitted process > regressive_alignment (LIM.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [38/f2682b] Submitted process > regressive_alignment (LIM.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [f1/3ad985] Submitted process > regressive_alignment (gpdh.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [a2/aa6a70] Submitted process > regressive_alignment (biotin_lipoyl.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [11/084d2f] Submitted process > regressive_alignment (HLH.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [f9/b86dbc] Submitted process > regressive_alignment (trfl.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [ee/dad2ac] Submitted process > regressive_alignment (toxin.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [17/24b4f2] Submitted process > regressive_alignment (ltn.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [0a/b9fe9a] Submitted process > regressive_alignment (gluts.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [75/249e5e] Submitted process > regressive_alignment (toxin.CLUSTALO.DPA.1000.MAFFT)
# [73/b714aa] Submitted process > regressive_alignment (uce.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [51/4d2121] Submitted process > regressive_alignment (ltn.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [8d/b837a6] Submitted process > regressive_alignment (phc.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [63/4aefb0] Submitted process > regressive_alignment (HLH.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [f3/f3feb1] Submitted process > regressive_alignment (proteasome.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [55/8f8abb] Submitted process > regressive_alignment (peroxidase.CLUSTALO.DPA.1000.MAFFT)
# [9d/8832d1] Submitted process > regressive_alignment (ace.CLUSTALO.DPA.1000.MAFFT)
# [c4/1be753] Submitted process > regressive_alignment (PDZ.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [a0/e2b3a3] Submitted process > regressive_alignment (myb_DNA-binding.CLUSTALO.DPA.1000.MAFFT)
# [55/10ea0e] Submitted process > regressive_alignment (Rhodanese.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [dc/bcfc60] Submitted process > regressive_alignment (LIM.CLUSTALO.DPA.1000.MAFFT)
# [8b/a5d2fc] Submitted process > regressive_alignment (mofe.CLUSTALO.DPA.1000.MAFFT)
# [39/73d3ee] Submitted process > regressive_alignment (biotin_lipoyl.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [28/812c60] Submitted process > regressive_alignment (HLH.CLUSTALO.DPA.1000.CLUSTALO)
# [3d/175230] Submitted process > regressive_alignment (trfl.CLUSTALO.DPA.1000.CLUSTALO)
# [3f/4adffc] Submitted process > regressive_alignment (HLH.CLUSTALO.DPA.1000.MAFFT)
# [c7/d6cb0f] Submitted process > regressive_alignment (ltn.CLUSTALO.DPA.1000.CLUSTALO)
# [47/3a256c] Submitted process > regressive_alignment (LIM.CLUSTALO.DPA.1000.CLUSTALO)
# [23/47de78] Submitted process > regressive_alignment (gluts.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [9f/52992f] Submitted process > regressive_alignment (gpdh.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [64/877181] Submitted process > regressive_alignment (uce.CLUSTALO.DPA.1000.MAFFT)
# [2e/770c61] Submitted process > regressive_alignment (proteasome.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [03/92635b] Submitted process > regressive_alignment (uce.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [89/86131a] Submitted process > regressive_alignment (phc.CLUSTALO.DPA.1000.MAFFT)
# [57/b93add] Submitted process > regressive_alignment (toxin.CLUSTALO.DPA.1000.CLUSTALO)
# [03/cce9b3] Submitted process > regressive_alignment (slectin.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [8d/85f07b] Submitted process > regressive_alignment (toxin.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [ad/570d57] Submitted process > regressive_alignment (ltn.CLUSTALO.DPA.1000.MAFFT)
# [69/47355f] Submitted process > regressive_alignment (slectin.CLUSTALO.DPA.1000.MAFFT)
# [54/cfeb14] Submitted process > regressive_alignment (slectin.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [36/eaa5ba] Submitted process > regressive_alignment (scorptoxin.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [80/5b3e5b] Submitted process > regressive_alignment (OTCace.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [24/abadab] Submitted process > regressive_alignment (scorptoxin.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [44/90c9cd] Submitted process > regressive_alignment (oxidored_q6.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [39/ed0fec] Submitted process > regressive_alignment (scorptoxin.CLUSTALO.DPA.1000.MAFFT)
# [ab/f1adb6] Submitted process > regressive_alignment (OTCace.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [69/ba472a] Submitted process > regressive_alignment (phc.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [27/4b156e] Submitted process > regressive_alignment (seatoxin.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [4a/5d928e] Submitted process > regressive_alignment (seatoxin.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [7f/392d7c] Submitted process > regressive_alignment (seatoxin.CLUSTALO.DPA.1000.CLUSTALO)
# [36/d578b8] Submitted process > regressive_alignment (Ald_Xan_dh_2.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [9b/4ae68d] Submitted process > regressive_alignment (myb_DNA-binding.CLUSTALO.DPA.1000.CLUSTALO)
# [0f/3045ac] Submitted process > regressive_alignment (ldh.CLUSTALO.DPA.1000.CLUSTALO)
# [59/eb680a] Submitted process > regressive_alignment (hormone_rec.CLUSTALO.DPA.1000.CLUSTALO)
# [a8/e06c36] Submitted process > regressive_alignment (subt.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [20/d82ff8] Submitted process > regressive_alignment (int.CLUSTALO.DPA.1000.MAFFT)
# [32/6e27f1] Submitted process > regressive_alignment (hla.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [b0/881b71] Submitted process > regressive_alignment (phoslip.CLUSTALO.DPA.1000.CLUSTALO)
# [66/b6d85a] Submitted process > regressive_alignment (phoslip.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [a9/29317c] Submitted process > regressive_alignment (oxidored_q6.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [f8/480b4f] Submitted process > regressive_alignment (phoslip.CLUSTALO.DPA.1000.MAFFT)
# [c5/fdb204] Submitted process > regressive_alignment (p450.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [8e/6bdcdb] Submitted process > regressive_alignment (cyt3.CLUSTALO.DPA.1000.CLUSTALO)
# [82/b3b9ca] Submitted process > regressive_alignment (seatoxin.CLUSTALO.DPA.1000.MAFFT)
# [93/1113bf] Submitted process > regressive_alignment (cyt3.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [d3/81eab7] Submitted process > regressive_alignment (Ald_Xan_dh_2.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [15/791204] Submitted process > regressive_alignment (lyase_1.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [26/231d40] Submitted process > regressive_alignment (cyt3.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [37/89a540] Submitted process > regressive_alignment (OTCace.CLUSTALO.DPA.1000.MAFFT)
# [67/00192c] Submitted process > regressive_alignment (slectin.CLUSTALO.DPA.1000.CLUSTALO)
# [19/0c315a] Submitted process > regressive_alignment (oxidored_q6.CLUSTALO.DPA.1000.CLUSTALO)
# [83/f6ca5a] Submitted process > regressive_alignment (Ald_Xan_dh_2.CLUSTALO.DPA.1000.CLUSTALO)
# [2e/1d71a7] Submitted process > regressive_alignment (Ald_Xan_dh_2.CLUSTALO.DPA.1000.MAFFT)
# [d4/d0d9ce] Submitted process > regressive_alignment (oxidored_q6.CLUSTALO.DPA.1000.MAFFT)
# [17/38a140] Submitted process > regressive_alignment (phc.CLUSTALO.DPA.1000.CLUSTALO)
# [4d/388cc7] Submitted process > regressive_alignment (phoslip.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [2e/d8801b] Submitted process > regressive_alignment (rrm.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [57/45e595] Submitted process > regressive_alignment (DMRL_synthase.CLUSTALO.DPA.1000.MAFFT)
# [19/1f64ed] Submitted process > regressive_alignment (tRNA-synt_2b.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [e0/c6176d] Submitted process > regressive_alignment (cyt3.CLUSTALO.DPA.1000.MAFFT)
# [c0/0d85fb] Submitted process > regressive_alignment (KAS.CLUSTALO.DPA.1000.MAFFT)
# [d9/e94a96] Submitted process > regressive_alignment (KAS.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [77/0fa2e3] Submitted process > regressive_alignment (ghf13.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [3a/e4950f] Submitted process > regressive_alignment (msb.CLUSTALO.DPA.1000.CLUSTALO)
# [45/3299ca] Submitted process > regressive_alignment (aldosered.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [d2/e5b262] Submitted process > regressive_alignment (gpdh.CLUSTALO.DPA.1000.MAFFT)
# [21/070c4d] Submitted process > regressive_alignment (gpdh.CLUSTALO.DPA.1000.CLUSTALO)
# [63/9c8fab] Submitted process > regressive_alignment (biotin_lipoyl.CLUSTALO.DPA.1000.CLUSTALO)
# [e6/133d89] Submitted process > regressive_alignment (proteasome.CLUSTALO.DPA.1000.MAFFT)
# [46/a36455] Submitted process > regressive_alignment (tim.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [ca/5a4e4e] Submitted process > regressive_alignment (scorptoxin.CLUSTALO.DPA.1000.CLUSTALO)
# [f3/26cdef] Submitted process > regressive_alignment (lyase_1.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [ad/9562f1] Submitted process > regressive_alignment (tim.CLUSTALO.DPA.1000.MAFFT)
# [95/ba138b] Submitted process > regressive_alignment (tim.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [7c/0c974b] Submitted process > regressive_alignment (cyclo.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [07/0c3e0c] Re-submitted process > guide_trees (rvp.MAFFT)
# [05/663071] Submitted process > regressive_alignment (KAS.CLUSTALO.DPA.1000.CLUSTALO)
# [52/10bf01] Submitted process > regressive_alignment (flav.CLUSTALO.DPA.1000.MAFFT)
# [74/8d42dd] Submitted process > regressive_alignment (flav.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [ee/1f54e5] Submitted process > regressive_alignment (DMRL_synthase.CLUSTALO.DPA.1000.CLUSTALO)
# [ad/083a33] Submitted process > regressive_alignment (ghf22.CLUSTALO.DPA.1000.CLUSTALO)
# [68/556896] Submitted process > regressive_alignment (DMRL_synthase.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [29/48ae6c] Submitted process > regressive_alignment (DMRL_synthase.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [f6/52e391] Submitted process > regressive_alignment (ghf22.CLUSTALO.DPA.1000.MAFFT)
# [18/0be3a8] Submitted process > regressive_alignment (TNF.CLUSTALO.DPA.1000.MAFFT)
# [7d/a1b1a2] Submitted process > regressive_alignment (ghf22.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [7f/54053e] Submitted process > regressive_alignment (rhv.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [40/1a0bfe] Submitted process > regressive_alignment (blmb.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [bf/30643a] Submitted process > regressive_alignment (OTCace.CLUSTALO.DPA.1000.CLUSTALO)
# [2f/17d212] Submitted process > regressive_alignment (uce.CLUSTALO.DPA.1000.CLUSTALO)
# [81/a579dd] Submitted process > regressive_alignment (peroxidase.CLUSTALO.DPA.1000.CLUSTALO)
# [7f/662a65] Submitted process > regressive_alignment (PDZ.CLUSTALO.DPA.1000.CLUSTALO)
# [15/12cb0f] Submitted process > regressive_alignment (hla.CLUSTALO.DPA.1000.MAFFT)
# [99/749635] Submitted process > regressive_alignment (adh.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [64/b6e4cd] Submitted process > regressive_alignment (biotin_lipoyl.CLUSTALO.DPA.1000.MAFFT)
# [1f/075f84] Submitted process > regressive_alignment (flav.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [37/209c41] Submitted process > regressive_alignment (annexin.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [74/6444f6] Submitted process > regressive_alignment (tim.CLUSTALO.DPA.1000.CLUSTALO)
# [fd/620df3] Submitted process > regressive_alignment (KAS.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [00/4d8b30] Submitted process > regressive_alignment (cyclo.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [d8/037db2] Submitted process > regressive_alignment (ghf22.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [be/158589] Submitted process > regressive_alignment (blm.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [bc/64a226] Submitted process > regressive_alignment (TNF.CLUSTALO.DPA.1000.CLUSTALO)
# [26/9eb09f] Submitted process > regressive_alignment (ghf1.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [56/415974] Submitted process > regressive_alignment (annexin.CLUSTALO.DPA.1000.CLUSTALO)
# [f9/61f292] Submitted process > regressive_alignment (cys.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [86/9f4590] Submitted process > regressive_alignment (icd.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [96/84f959] Submitted process > regressive_alignment (TNF.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [69/35d84b] Submitted process > regressive_alignment (TNF.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [dd/bf58b1] Submitted process > regressive_alignment (PDZ.CLUSTALO.DPA.1000.MAFFT)
# [98/d53127] Submitted process > regressive_alignment (hla.CLUSTALO.DPA.1000.CLUSTALO)
# [50/022993] Submitted process > regressive_alignment (proteasome.CLUSTALO.DPA.1000.CLUSTALO)
# [72/9bc300] Submitted process > regressive_alignment (lyase_1.CLUSTALO.DPA.1000.MAFFT)
# [d2/76ea5c] Submitted process > regressive_alignment (tRNA-synt_2b.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [92/3a75bc] Submitted process > regressive_alignment (rvp.CLUSTALO.DPA.1000.MAFFT_PARTTREE)
# [9f/28da31] Re-submitted process > guide_trees (rvp.MAFFT-FFTNS1)
# [f6/ca2ff6] Submitted process > regressive_alignment (cyclo.CLUSTALO.DPA.1000.MAFFT)
# [e9/1e6f35] Submitted process > regressive_alignment (ghf1.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [8a/dfb203] Submitted process > regressive_alignment (cys.CLUSTALO.DPA.1000.MAFFT)
# [aa/f5b6e6] Submitted process > regressive_alignment (cys.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [2a/4c4e5c] Submitted process > regressive_alignment (icd.CLUSTALO.DPA.1000.MAFFT-FFTNS1)
# [13/b58853] Submitted process > regressive_alignment (Sulfotransfer.CLUSTALO.DPA.1000.CLUSTALO)
# [e4/de0cbe] Submitted process > regressive_alignment (mofe.CLUSTALO.DPA.1000.CLUSTALO)
# ^C
#
# Execution status: failed runName: fabulous_minsky
# WARN: Killing pending tasks (100)
